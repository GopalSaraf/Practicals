# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Download dataset
# !wget -N "https://gopalsaraf.com/practicals/admissions.csv"

# Create dataframe
df = pd.read_csv("admissions.csv")
# Out:
# --2023-10-06 04:57:52--  https://gopalsaraf.com/practicals/admissions.csv
# Resolving gopalsaraf.com (gopalsaraf.com)... 89.117.157.149, 2a02:4780:11:1101:0:28f7:5612:3
# Connecting to gopalsaraf.com (gopalsaraf.com)|89.117.157.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12903 (13K) [text/plain]
# Saving to: ‘admissions.csv’
#
# admissions.csv      100%[===================>]  12.60K  --.-KB/s    in 0s
#
# 2023-10-06 04:57:52 (207 MB/s) - ‘admissions.csv’ saved [12903/12903]

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
# check null values
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
X = df.iloc[:, 1:-1]
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
y = df.iloc[:, -1]
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
y = y.mask(y >= 0.8, 1)
y = y.mask(y < 0.8, 0)

y
# Out:
# 0      1.0
# 1      0.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 395    1.0
# 396    1.0
# 397    1.0
# 398    0.0
# 399    1.0
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Splitting data
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.25)

# %%
from sklearn.tree import DecisionTreeClassifier

# Creating Decision Tree classifer object
clf = DecisionTreeClassifier()

# %%
# Training Decision Tree Classifer
clf = clf.fit(X_train, Y_train)

# %%
#Predicting for the test data
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics

print("confusion matrix:\n")
print(metrics.confusion_matrix(Y_test, y_pred))
# Out:
# confusion matrix:
#
# [[64  6]
#  [ 7 23]]

# %%
print("1. Accuracy Score:", metrics.accuracy_score(Y_test, y_pred))
print("2. Precision Score:",metrics.precision_score(Y_test, y_pred))
print("3. Recall Score:", metrics.recall_score(Y_test, y_pred))
print("4. f1 Score:", metrics.f1_score(Y_test, y_pred))
# Out:
# 1. Accuracy Score: 0.87
# 2. Precision Score: 0.7931034482758621
# 3. Recall Score: 0.7666666666666667
# 4. f1 Score: 0.7796610169491527
