# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
# Loadin the dataset
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

# %%
# Dataset
print('Training data shape : ', X_train.shape, y_train.shape)
print('Testing data shape : ', X_test.shape, y_test.shape)
# Out:
# Training data shape :  (50000, 32, 32, 3) (50000, 1)
# Testing data shape :  (10000, 32, 32, 3) (10000, 1)

# %%
num_classes = 10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Displaying few images
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(X_train[i])
    plt.axis('off')
    plt.title(class_names[y_train[i][0]], fontsize=10)
plt.show()

# %%
# Normalizing the data
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
print('Training data shape : ', X_train.shape, y_train.shape)
print('Testing data shape : ', X_test.shape, y_test.shape)
# Out:
# Training data shape :  (50000, 32, 32, 3) (50000, 10)
# Testing data shape :  (10000, 32, 32, 3) (10000, 10)

# %%
# Building the model
model = keras.models.Sequential([
    # CNN layers
    keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3), name='conv1'),
    keras.layers.MaxPooling2D(pool_size=(2, 2), name='pool1'),
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name='conv2'),
    keras.layers.MaxPooling2D(pool_size=(2, 2), name='pool2'),
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name='conv3'),

    # Dense layers
    keras.layers.Flatten(name='flatten'),
    keras.layers.Dense(64, activation='relu', name='dense1'),
    keras.layers.Dense(10, activation='softmax', name='dense2')
])

# Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /opt/homebrew/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling2D)            │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling2D)            │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense1 (Dense)                  │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense2 (Dense)                  │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,570 (478.79 KB)
#  Trainable params: 122,570 (478.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training the model
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.3496 - loss: 1.7512 - val_accuracy: 0.5572 - val_loss: 1.2325
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5710 - loss: 1.2071 - val_accuracy: 0.6219 - val_loss: 1.0637
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6327 - loss: 1.0327 - val_accuracy: 0.6506 - val_loss: 0.9889
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.6700 - loss: 0.9357 - val_accuracy: 0.6779 - val_loss: 0.9319
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7054 - loss: 0.8457 - val_accuracy: 0.6768 - val_loss: 0.9386
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7222 - loss: 0.7868 - val_accuracy: 0.6868 - val_loss: 0.9052
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7377 - loss: 0.7429 - val_accuracy: 0.6932 - val_loss: 0.9023
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7539 - loss: 0.7019 - val_accuracy: 0.7057 - val_loss: 0.8570
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.7690 - loss: 0.6538 - val_accuracy: 0.7046 - val_loss: 0.8723
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.7835 - loss: 0.6170 - val_accuracy: 0.7062 - val_loss: 0.8942
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7937 - loss: 0.5849 - val_accuracy: 0.7115 - val_loss: 0.8781
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8059 - loss: 0.5496 - val_accuracy: 0.7142 - val_loss: 0.8895
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.8188 - loss: 0.5230 - val_accuracy: 0.7049 - val_loss: 0.9252
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.8262 - loss: 0.4886 - val_accuracy: 0.7061 - val_loss: 0.9086
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8344 - loss: 0.4576 - val_accuracy: 0.6966 - val_loss: 0.9735
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8461 - loss: 0.4329 - val_accuracy: 0.7096 - val_loss: 0.9546
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8553 - loss: 0.4084 - val_accuracy: 0.7040 - val_loss: 1.0345
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8608 - loss: 0.3839 - val_accuracy: 0.6983 - val_loss: 1.0384
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8714 - loss: 0.3603 - val_accuracy: 0.7053 - val_loss: 1.0954
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8753 - loss: 0.3501 - val_accuracy: 0.7060 - val_loss: 1.1102

# %%
# Plotting the accuracy and loss
plt.figure(figsize=(10, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7086 - loss: 1.1152

# %%
# Predictions
predictions = model.predict(X_test)

# Displaying few images
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(X_test[i])
    plt.axis('off')
    plt.title(f'Actual: {class_names[np.argmax(y_test[i])]} \n Predicted: {class_names[np.argmax(predictions[i])]}', fontsize=10, color='green' if np.argmax(y_test[i]) == np.argmax(predictions[i]) else 'red')
    plt.subplots_adjust(top=1.01)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
